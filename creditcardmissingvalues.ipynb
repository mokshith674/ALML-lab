# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\Hp\\Documents\\CreditCard_DV1.csv')
df
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer          45.0      M              3.0
# 1   818770008  Existing Customer          49.0      F              5.0
# 2   713982108  Existing Customer          51.0      M              3.0
# 3   769911858  Existing Customer          40.0      F              4.0
# 4   709106358  Existing Customer          40.0      M              3.0
# ..        ...                ...           ...    ...              ...
# 95  719712633  Existing Customer          64.0      M              1.0
# 96  772629333  Existing Customer          45.0      M              3.0
# 97  720336708  Existing Customer          53.0      M              3.0
# 98  802013583  Existing Customer          56.0      M              3.0
# 99  711887583  Attrited Customer          47.0      M              2.0
#
#    Education_Level Income_Category  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
df.isna()
# Out:
#     CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0       False           False         False   False            False
# 1       False           False         False   False            False
# 2       False           False         False   False            False
# 3       False           False         False   False            False
# 4       False           False         False   False            False
# ..        ...             ...           ...     ...              ...
# 95      False           False         False   False            False
# 96      False           False         False   False            False
# 97      False           False         False   False            False
# 98      False           False         False   False            False
# 99      False           False         False   False            False
#
#     Education_Level  Income_Category  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
df=df.drop(['Credit_Limit'],axis=1)
df.isnull().sum()
# Out:
# CLIENTNUM               0
# Attrition_Flag          8
# Customer_Age           13
# Gender                  5
# Dependent_count        15
# Education_Level        31
# Income_Category        33
# Total_Revolving_Bal    22
# Avg_Purchase           18
# Total_Trans_Amt         2
# dtype: int64

# %%
df
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer          45.0      M              3.0
# 1   818770008  Existing Customer          49.0      F              5.0
# 2   713982108  Existing Customer          51.0      M              3.0
# 3   769911858  Existing Customer          40.0      F              4.0
# 4   709106358  Existing Customer          40.0      M              3.0
# ..        ...                ...           ...    ...              ...
# 95  719712633  Existing Customer          64.0      M              1.0
# 96  772629333  Existing Customer          45.0      M              3.0
# 97  720336708  Existing Customer          53.0      M              3.0
# 98  802013583  Existing Customer          56.0      M              3.0
# 99  711887583  Attrited Customer          47.0      M              2.0
#
#    Income_Category  Total_Revolving_Bal  Avg_Purchase  Total_Trans_Amt
# ...

# %%
df=pd.read_csv('C:\\Users\\Hp\\Documents\\CreditCard_DV1.csv')
df
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer          45.0      M              3.0
# 1   818770008  Existing Customer          49.0      F              5.0
# 2   713982108  Existing Customer          51.0      M              3.0
# 3   769911858  Existing Customer          40.0      F              4.0
# 4   709106358  Existing Customer          40.0      M              3.0
# ..        ...                ...           ...    ...              ...
# 95  719712633  Existing Customer          64.0      M              1.0
# 96  772629333  Existing Customer          45.0      M              3.0
# 97  720336708  Existing Customer          53.0      M              3.0
# 98  802013583  Existing Customer          56.0      M              3.0
# 99  711887583  Attrited Customer          47.0      M              2.0
#
#    Education_Level Income_Category  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
df['Credit_Limit']=df['Credit_Limit'].fillna(0)
df['Credit_Limit'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer          45.0      M              3.0
# 1   818770008  Existing Customer          49.0      F              5.0
# 2   713982108  Existing Customer          51.0      M              3.0
# 3   769911858  Existing Customer          40.0      F              4.0
# 4   709106358  Existing Customer          40.0      M              3.0
# ..        ...                ...           ...    ...              ...
# 95  719712633  Existing Customer          64.0      M              1.0
# 96  772629333  Existing Customer          45.0      M              3.0
# 97  720336708  Existing Customer          53.0      M              3.0
# 98  802013583  Existing Customer          56.0      M              3.0
# 99  711887583  Attrited Customer          47.0      M              2.0
#
#    Education_Level Income_Category  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
mean=df['Total_Revolving_Bal'].mean()
print(mean)
df['Total_Revolving_Bal']=df['Total_Revolving_Bal'].fillna(mean)
df['Total_Revolving_Bal']
# Out:
# 1379.2948717948718
# 0     1379.294872
# 1      864.000000
# 2     1379.294872
# 3     1379.294872
# 4        0.000000
#          ...
# 95    1379.294872
# 96    1379.294872
# 97    1706.000000
# 98    2250.000000
# 99    1628.000000
# Name: Total_Revolving_Bal, Length: 100, dtype: float64

# %%
df
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer          45.0      M              3.0
# 1   818770008  Existing Customer          49.0      F              5.0
# 2   713982108  Existing Customer          51.0      M              3.0
# 3   769911858  Existing Customer          40.0      F              4.0
# 4   709106358  Existing Customer          40.0      M              3.0
# ..        ...                ...           ...    ...              ...
# 95  719712633  Existing Customer          64.0      M              1.0
# 96  772629333  Existing Customer          45.0      M              3.0
# 97  720336708  Existing Customer          53.0      M              3.0
# 98  802013583  Existing Customer          56.0      M              3.0
# 99  711887583  Attrited Customer          47.0      M              2.0
#
#    Education_Level Income_Category  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
df['Avg_Purchase']=df['Avg_Purchase'].fillna(df['Avg_Purchase'].mode()[0])
df['Avg_Purchase']
# Out:
# 0     11914.0
# 1      7392.0
# 2      3418.0
# 3       796.0
# 4      4716.0
#        ...
# 95    34516.0
# 96    34516.0
# 97     2083.0
# 98     7439.0
# 99     3821.0
# Name: Avg_Purchase, Length: 100, dtype: float64

# %%
df['Total_Trans_Amt'].fillna(df['Total_Trans_Amt'].median())
# Out:
# 0     1144.0
# 1     1291.0
# 2     1887.0
# 3     1171.0
# 4      816.0
#        ...
# 95    1311.5
# 96    1311.5
# 97    1609.0
# 98    1158.0
# 99     836.0
# Name: Total_Trans_Amt, Length: 100, dtype: float64

# %%
df.fillna(method='ffill')
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer          45.0      M              3.0
# 1   818770008  Existing Customer          49.0      F              5.0
# 2   713982108  Existing Customer          51.0      M              3.0
# 3   769911858  Existing Customer          40.0      F              4.0
# 4   709106358  Existing Customer          40.0      M              3.0
# ..        ...                ...           ...    ...              ...
# 95  719712633  Existing Customer          64.0      M              1.0
# 96  772629333  Existing Customer          45.0      M              3.0
# 97  720336708  Existing Customer          53.0      M              3.0
# 98  802013583  Existing Customer          56.0      M              3.0
# 99  711887583  Attrited Customer          47.0      M              2.0
#
#    Education_Level Income_Category  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
df.fillna(method='bfill')
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0   768805383  Existing Customer          45.0      M              3.0
# 1   818770008  Existing Customer          49.0      F              5.0
# 2   713982108  Existing Customer          51.0      M              3.0
# 3   769911858  Existing Customer          40.0      F              4.0
# 4   709106358  Existing Customer          40.0      M              3.0
# ..        ...                ...           ...    ...              ...
# 95  719712633  Existing Customer          64.0      M              1.0
# 96  772629333  Existing Customer          45.0      M              3.0
# 97  720336708  Existing Customer          53.0      M              3.0
# 98  802013583  Existing Customer          56.0      M              3.0
# 99  711887583  Attrited Customer          47.0      M              2.0
#
#    Education_Level Income_Category  Credit_Limit  Total_Revolving_Bal  \
# ...
